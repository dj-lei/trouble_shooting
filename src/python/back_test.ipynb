# %%
from file_operate import *

path = 'exiosuu_LTE_TALAGAKOCAK_GH_2052.log'
fe = FileOperate(path)

# %%
len(fe.inverted_index_table.keys())
# Out:
# 3601

# %%
list(fe.inverted_index_table.keys())
# Out:
# ['read',
#  'BXP_2052',
#  'lhsh',
#  'te',
#  'fruacc',
#  'coli',
#  'log',
#  'restarts',
#  'Trace',
#  'from',
#  'before',
#  'trDcProc',
#  'deviceId',
#  'BUSY',
#  'cpu_id',
#  'radio6626',
#  'clientId',
#  'trDcHandler.cc',
#  'com_ericsson_trithread',
#  'for',
#  'Device',
#  'INFO',
#  'process',
#  '?.?????????',
#  'state',
#  'msg',
#  'DEACTIVATE',
#  'fileAndLine',
#  'DC_TR_DEACTIVATE_CFM',
#  'trDcServer.cc',
#  'DC_TR_ACTIVATE_REQ',
#  'clientRef',
#  'serverRef',
#  'Using',
#  'Could',
#  'not',
#  'trDcSubscriber.cc',
#  'actIndToActivateIndThreshold',
#  'database.',
#  'm_actIndToActivateIndThreshold',
#  'localCpriPort',
#  'EquipCtrl',
#  'linkCtrlCpriRadonVisby.cc',
#  'TxTimingPhaseCtrlG',
#  'Received',
#  'txTimingPhaseCtrl.cc',
#  'EVENT_ACTIVATE',
#  'carrierId',
#  'logManager.cc',
#  'support',
#  'does',
#  'different',
#  'txChangeCycleStatePrepare.cc',
#  'Branch',
#  'TxBranchCtrlD',
#  'level',
#  'power',
#  'by',
#  'cycle',
# ...

# %%
not True
